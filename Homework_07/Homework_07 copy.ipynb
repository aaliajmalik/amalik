# %% [markdown]
# # 1. Partial Correlations
#
# Modify the code of the `partial_cor()` function from Class 09d, so that it takes as input a correlation matrix and the name of one variable, and returns the partial correlation for each pair of variables controlled for the variable you passed to the function.
#
# For example, if you use the correlation matrices that we calculated in Class 9d, you could use the function by calling: `partial_cor(cor1, CAI)`, this would return the partial correlation of each pair of variables (minus CAI) controlled by CAI.
#
# To do this, please save the `result` dataframe from Class 9d to a file, copy the file to the homework directory, read the file into a datframe, calculate the correlation matrix, and finally test your function.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#Read the data from a CSV file with pandas read_csv function
data2 = pd.read_csv('cor1_df.csv', index_col=0)
data2.head()
# Out:
#                   CAI        dS        dN     dN/dS  dS adjusted  \
# CAI          1.000000 -0.572301 -0.387714 -0.321217     0.003920
# dS          -0.572301  1.000000  0.474832  0.247113     0.817794
# dN          -0.387714  0.474832  1.000000  0.947007     0.306928
# dN/dS       -0.321217  0.247113  0.947007  1.000000     0.075907
# dS adjusted  0.003920  0.817794  0.306928  0.075907     1.000000
#
#              dN/dS adjusted   fitness       fdS       fdN     fdNdS    fdSadj  \
# CAI               -0.418473 -0.144052 -0.681322 -0.541741 -0.396838  0.006135
# dS                 0.347617  0.141512  0.943893  0.565637  0.329857  0.811856
# dN                 0.972501  0.211832  0.417595  0.851489  0.829777  0.294847
# dN/dS              0.987734  0.209808  0.213819  0.825245  0.870099  0.062343
# dS adjusted        0.130210  0.071469  0.672864  0.309562  0.123737  0.994314
#
#              fdNdSadj
# CAI         -0.559475
# dS           0.467328
# dN           0.846957
# dN/dS        0.853203
# dS adjusted  0.177234

# %%
cor1 = result.corr()
cor2 = result.corr(method='spearman')
cor1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1h/d7jrhj0912qc6jg546194yyr0000gn/T/ipykernel_5583/2354887395.py in <module>
# ----> 1 cor1 = result.corr()
#       2 cor2 = result.corr(method='spearman')
#       3 cor1
#
# NameError: name 'result' is not defined

# %%
def partial_cor(cor,x,y,z):
    from math import sqrt
    rdk = ((cor[x][y]-cor[x][z]*cor[y][z])/ 
       (sqrt(1-cor[x][z]**2)*sqrt(1-cor[y][z]**2)))
    return rdk

# %%
def partial_cor_modified(cor_matrix, variable):
    l = []  # Initialize empty list l

    # Iterate through each variable a in cor_matrix
    for a in cor_matrix.columns[2:]:
        # Skip if a is the same as the control variable
        if a == variable:
            continue
        # Iterate through each variable b in cor_matrix
        for b in cor_matrix.columns[2:]:
            # Skip if b is the same as the control variable or same as a
            if b == variable or b == a:
                continue
            # Calculate partial correlation and append to list l
            l.append(partial_cor(cor_matrix, a, b, variable))

    return l

# %%
cor2 = partial_cor_modified(data2, "CAI")
cor2
# Out:
# [0.9421901844535256,
#  0.33462447831134406,
#  0.967827525612897,
#  0.17100039957410024,
#  0.22740493053170016,
#  0.8278918018943022,
#  0.798870962665815,
#  0.32245328441690096,
#  0.8246445829377812,
#  0.9421901844535256,
#  0.08148541102469395,
#  0.992111308619733,
#  0.17450706523594292,
#  -0.007260460293863888,
#  0.8181248231600826,
#  0.8543363859936984,
#  0.06791359954276836,
#  0.8580338214908867,
#  0.33462447831134406,
#  0.08148541102469395,
#  0.14517462816299867,
#  0.07279303960209084,
#  0.9228885752850715,
#  0.37081625448113076,
#  0.1365015616051732,
#  0.994315886956042,
#  0.21648023382169712,
#  0.967827525612897,
#  0.992111308619733,
#  0.14517462816299867,
#  0.173285258380601,
#  0.05662762089873396,
#  0.8128791151019522,
#  0.829747028007271,
#  0.13276342140933564,
#  0.8424099632970898,
#  0.17100039957410024,
#  0.17450706523594292,
#  0.07279303960209084,
#  0.173285258380601,
#  0.06803761805662417,
#  0.2249501955584557,
#  0.21668038555836,
#  0.07236832643265845,
#  0.22363707003539596,
#  0.22740493053170016,
#  -0.007260460293863888,
#  0.9228885752850715,
#  0.05662762089873396,
#  0.06803761805662417,
#  0.304331936918423,
#  0.05229794159722761,
#  0.9334688686702046,
#  0.15418024960369814,
#  0.8278918018943022,
#  0.8181248231600826,
#  0.37081625448113076,
#  0.8128791151019522,
#  0.2249501955584557,
#  0.304331936918423,
#  0.9655912922808731,
#  0.3686476174508669,
#  0.9859844423237615,
#  0.798870962665815,
#  0.8543363859936984,
#  0.1365015616051732,
#  0.829747028007271,
#  0.21668038555836,
#  0.05229794159722761,
#  0.9655912922808731,
#  0.1314641640872058,
#  0.9903327419808696,
#  0.32245328441690096,
#  0.06791359954276836,
#  0.994315886956042,
#  0.13276342140933564,
#  0.07236832643265845,
#  0.9334688686702046,
#  0.3686476174508669,
#  0.1314641640872058,
#  0.2131101369198255,
#  0.8246445829377812,
#  0.8580338214908867,
#  0.21648023382169712,
#  0.8424099632970898,
#  0.22363707003539596,
#  0.15418024960369814,
#  0.9859844423237615,
#  0.9903327419808696,
#  0.2131101369198255]

# %% [markdown]
# # 2. Results from Wall et al.
#
# Download the HTML page for the Wall et al paper from the PNAS website (https://www.pnas.org/content/102/15/5483/) using your browser. Then use BeautifulSoup to parse the HTML and scrape Table 1, finally print the value of the BeautifulSoup variable containing the table using the `IPYthon.display.Markdown` function to display the table.
#
# (Unfortunately, we cannot automatically download the HMTL for the page anymore because the PNAS site uses Cloudfare to prevent users from scraping so we cannot use python's request package to download the page)

# %%
url = "https://www.pnas.org/doi/10.1073/pnas.0501761102"

# %%
import requests
page  = requests.get(url)
print(type(page))
# Out:
# <class 'requests.models.Response'>

# %%
data = page.text
print(data)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
#     <title>Just a moment...</title>
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#     <meta name="robots" content="noindex,nofollow">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet">
#     <meta http-equiv="refresh" content="35">
#
# </head>
# <body class="no-js">
#     <div class="main-wrapper" role="main">
#     <div class="main-content">
#         <noscript>
#             <div id="challenge-error-title">
#                 <div class="h2">
#                     <span class="icon-wrapper">
#                         <div class="heading-icon warning-icon"></div>
#                     </span>
#                     <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
#                 </div>
#             </div>
#         </noscript>
#         <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/jsch/nojs/transparent.gif?ray=7bdb9ed3fc3d1005')"></div>
#         <form id="challenge-form" action="/doi/10.1073/pnas.0501761102?__cf_chl_f_tk=kOEGTGYURTpiryGROyU4l8xvgzSo_l4rIxyyXxNaT7A-1682478497-0-gaNycGzNCa
WrdaDzroCqg3L0rMkv2wCPq-LdgZaHxdE29urn9WuOP-Edaq529t1hX5I0RZaL6dg8E5Sype79AajDeG1-kSSNHM0c3wDFObP0lr1D26YHLh5tWX0c7XfEOFLFToVFsMd-YBMXKUc-ksLigG7WUffUPxgoxfpby_7cKdwPfL-gaJW5vAoMBPS9q--tP6baY3ckw6yib43Ud5LBJYYG3i6ojL2VZGDfttyHpiiJga0uTgX247DaM41fq2U8Kb2KUf4canZiYO1-YPGypiYdc-zYthfJ39Pd0xME1zsvkWVaeuay4dZdAKQ9zhX536aYclgXSLDhUwGht5CusxMK4ReUHYfGdtGW-T7B0p4v7BODLTbQRSLljMVfAOwt0AXZmqJ3p7dkR9fM5XQULKzN3heVwsYPxYOUyY9fZY_LONv7f0ELDftFvJdKwFkUIGc1TMi_JZkWQdmDbruMU17u3Zooz7JjD-q3Fuuak6us_QMvHqLVChYYugEukNIDxRoLN9_rUySMSrAJonKzJqft7wUhzz0wYXS4yFwJewLKGJdCgYA_lRLXl0rLvCgw2qist7xreVKc3HlFOxBpqCGyaKOckGlpV30-8A9L55RBhqJL5Ms0jTItbWkETiPZ8wxWsp71UsGosFsVy7AVu8s4p3O2MAueCWGutRoEhnE3fz5mwY3bGqiHNx6zSI6y9WxsREa46z3pNqgmCpEpsAbxAmixzAbwKy46Q95gsez2W7LJ04USjtC4gk1wrf6qUDIyLC04ppUeZQbjaXIxaEmzoT">
#         </form>
#     </div>
# </div>
# <script>
#     (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cZone: 'www.pnas.org',
#             cType: 'non-interactive',
#             cNounce: '51962',
#             cRay: '7bdb9ed3fc3d1005',
#             cHash: '6a041431ac7b7ef',
#             cUPMDTk: "\/doi\/10.1073\/pnas.0501761102?__cf_chl_tk=kOEGTGYURTpiryGROyU4l8xvgzSo_l4rIxyyXxNaT7A-1682478497-0-gaNycGzNCaU",
#             cFPWv: 'b',
#             cTTimeMs: '1000',
#             cMTimeMs: '60000',
#             cTplV: 5,
#             cTplB: 'cf',
#             cK: "",
#             cRq: {
#                 ru: 'aHR0cHM6Ly93d3cucG5hcy5vcmcvZG9pLzEwLjEwNzMvcG5hcy4wNTAxNzYxMTAy',
#                 ra: 'cHl0aG9uLXJlcXVlc3RzLzIuMjguMQ==',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY4MjQ3ODQ5Ny45MjAwMDA=',
#                 m: 'IjGQ9PikB20ZqseFj6xlN3wvIhnCzgLqWk/9Vl/zEis=',
#                 i1: 'wrz1Eq3rU6DWh8solBVkMw==',
#                 i2: 'LES+kHqt6gxS3Ch3k5GV/Q==',
#                 zh: '3XlKis5p8b5hgWF1bd9UgdW3b/8bjeC7/AQO0MH0R2I=',
#                 uh: 'SLdVolODg++SO356HusO5I/hbfOpiiOxQXj62i/MUkA=',
#                 hh: 'xx1TTDio6c75cUlsE4Atc65FbQFO1vgvVEBu0v9Ngqw=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/jsch/js/transparent.gif?ray=7bdb9ed3fc3d1005');
#         trkjs.setAttribute('alt', '');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/b/orchestrate/jsch/v1?ray=7bdb9ed3fc3d1005';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, location.href.length - window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/doi\/10.1073\/pnas.0501761102?__cf_chl_rt_tk=kOEGTGYURTpiryGROyU4l8xvgzSo_l4rIxyyXxNaT7A-1682478497-0-gaNycGzNCaU" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
# </script>
#
#
# </body>
# </html>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(data)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <title>Just a moment...</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="noindex,nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"/>
# <meta content="35" http-equiv="refresh"/>
# </head>
# <body class="no-js">
# <div class="main-wrapper" role="main">
# <div class="main-content">
# <noscript>
# <div id="challenge-error-title">
# <div class="h2">
# <span class="icon-wrapper">
# <div class="heading-icon warning-icon"></div>
# </span>
# <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
# </div>
# </div>
# </noscript>
# <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/jsch/nojs/transparent.gif?ray=7bdb9ed3fc3d1005')"></div>
# <form action="/doi/10.1073/pnas.0501761102?__cf_chl_f_tk=kOEGTGYURTpiryGROyU4l8xvgzSo_l4rIxyyXxNaT7A-1682478497-0-gaNycGzNCaU" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
# <input name="md" type="hidden" value="mqAcFgr_xw8Gy1l.jwQOecpl4LEHR_Xfd8WKoLaxvEg-1682478497-0-Afwk5TtD5NCK3Brk7c0HFEISCzvV6y5Snvka7OG1QdRT5XkAkd-jCJMdNFsmpYiGbY4qsVr0oyIKRNbK91Pkz_qZMUukiQC3mCO64i4uJTi2rjLeRLdR0AGuMFjQiHZ1pN29h_Q4BkrCNvzHzSwc5_3DYWDV10AHvzno9bk01gFfxCCDggtzhKymyWtHZ-rXhf1X8wZq4df2jZhwxcP6sAus35EBoaVmRCYxYF2dxqVmiEWw1PBQHV-Wno9HwtOIAqAyZb9ZR0EyoIlpo098iNfBb3loefQhDLpeL1PnTTY0Dt5TXMbghOeLdoQGdvjL_2UeMBqx-6jjCKcKB4fGKEe4Qsg3Kn9EQAJFk9ybzNubY_hBdl_UcFKo-x4xy8X_UPxwPa3ophpb3JjtlDMxX7ypxbRcPviVvtazDAUebaf8oa4xfs3hz7ZH-2IS1G8jZicGGO8EeR23NNSI7qe6ARaA6zD04fyuZaw-FawlSMOQqfDPlJsa30ToZM5gjzSfel9TFrWxkN1PWQhAsJY6iEeIcfqrm8C8EKDkWzm683Se1z77f4B0UlI7S-70dwRUs_WqIP6kr9sOh-CR5NwG54726h-389-1Kor5hCYpYGeVVIK02vVCNh0I-V2pIi8yFfMGYQNKzSxNBq0drkV0zp-JFoXK1aY2ZJyoQbqstrP-AoJokVfXKr2pRiDLghrbPwNhGr1SA0KCf1Hq3KzowNg4GZFYo8LgfPeAT2L9ntFc14YKJPed4z49zpd74Yp8FkA-k4Sp_tU-ljDUY8iBMH7VlJllEkHk8Q8LhOYuNEtfgheOJEgGh2xR6MsXVozBsCRqib-btRoG5SGLZECeI4vh_F2QZqwWjfAypKojMdYjzIbD2shZo3bLrz79dSrz81YfP7PZF8y9KaHQDzd10Yrp1Np_CoLHgEdtiZ-gqXPxdieTrWTSzIkbIPxCwcrqYx6mM-VExcQpzeamXbfBbKbcT34CVUSxjxLGn0ecfYS0_OR0pkmsT-i9OrKJDDkCbrKOQ1rINr_ERS6UoC7XGUfTnusYhkqMqh26cjl4r60DV_aoQDpqK5-hYAvxPMfzHffcPFWRcc67HGCWNrMSJi6WuvYjb8dUM11AaWc9ptAePNuC6fyS0_PxsEA9Fbv0qh-MyoA1FCQfzy67Zf2FC0oEgpqIpOHRx-6izqOjqlSr_SuwMVu1aAioRTe1ZhMlRoeyDYd0RAsW23V0rz-Vgx75ncI6ZXF5FCU1JVUm4OXUjQ5R4MWaYzYfsKMkiHc9vBAIFhxvC8d44aYX7tuaXO_3IlFcZ5ZShIdJHXYpsUkQh03YxrKIjLdpIOwTFnjEaYmeVSFjy9isNUSx62nZKJSmOzmOrB1IiqvpWc5mU-FeUqKFpa0nK6XAnB06VuwXA0i-2yz-lsOHWoVz25kl35iOvSiTESM4mYXpoh6Ty8U7zJ0PTuib_F7wA4o3kHXJvKYQrCGfW9vV-4V7DdpRadwpE-AIeY2In3NKvqWiCkrsmGkjBbVO_dirxAvOe_cZ5KJcff1P0urDmJamIBcKDFnEn0PoqsVG8X3Ltm-Tk0bSsaCi6xSWJsYd4LApo4RocwdAhvNiDleQook3AHQOQ7--WrdaDzroCqg3L0rMkv2wCPq-LdgZaHxdE29urn9WuOP-Edaq529t1hX5I0RZaL6dg8E5Sype79AajDeG1-kSSNHM0c3wDFObP0lr1D26YHLh5tWX0c7XfEOFLFToVFsMd-YBMXKUc-ksLigG7WUffUPxgoxfpby_7cKdwPfL-gaJW5vAoMBPS9q--tP6baY3ckw6yib43Ud5LBJYYG3i6ojL2VZGDfttyHpiiJga0uTgX247DaM41fq2U8Kb2KUf4canZiYO1-YPGypiYdc-zYthfJ39Pd0xME1zsvkWVaeuay4dZdAKQ9zhX536aYclgXSLDhUwGht5CusxMK4ReUHYfGdtGW-T7B0p4v7BODLTbQRSLljMVfAOwt0AXZmqJ3p7dkR9fM5XQULKzN3heVwsYPxYOUyY9fZY_LONv7f0ELDftFvJdKwFkUIGc1TMi_JZkWQdmDbruMU17u3Zooz7JjD-q3Fuuak6us_QMvHqLVChYYugEukNIDxRoLN9_rUySMSrAJonKzJqft7wUhzz0wYXS4yFwJewLKGJdCgYA_lRLXl0rLvCgw2qist7xreVKc3HlFOxBpqCGyaKOckGlpV30-8A9L55RBhqJL5Ms0jTItbWkETiPZ8wxWsp71UsGosFsVy7AVu8s4p3O2MAueCWGutRoEhnE3fz5mwY3bGqiHNx6zSI6y9WxsREa46z3pNqgmCpEpsAbxAmixzAbwKy46Q95gsez2W7LJ04USjtC4gk1wrf6qUDIyLC04ppUeZQbjaXIxaEmzoT"/>
# </form>
# </div>
# </div>
# <script>
#     (function(){
#         window._cf_chl_opt={
#             cvId: '2',
#             cZone: 'www.pnas.org',
#             cType: 'non-interactive',
#             cNounce: '51962',
#             cRay: '7bdb9ed3fc3d1005',
#             cHash: '6a041431ac7b7ef',
#             cUPMDTk: "\/doi\/10.1073\/pnas.0501761102?__cf_chl_tk=kOEGTGYURTpiryGROyU4l8xvgzSo_l4rIxyyXxNaT7A-1682478497-0-gaNycGzNCaU",
#             cFPWv: 'b',
#             cTTimeMs: '1000',
#             cMTimeMs: '60000',
#             cTplV: 5,
#             cTplB: 'cf',
#             cK: "",
#             cRq: {
#                 ru: 'aHR0cHM6Ly93d3cucG5hcy5vcmcvZG9pLzEwLjEwNzMvcG5hcy4wNTAxNzYxMTAy',
#                 ra: 'cHl0aG9uLXJlcXVlc3RzLzIuMjguMQ==',
#                 rm: 'R0VU',
#                 d: '...',
#                 t: 'MTY4MjQ3ODQ5Ny45MjAwMDA=',
#                 m: 'IjGQ9PikB20ZqseFj6xlN3wvIhnCzgLqWk/9Vl/zEis=',
#                 i1: 'wrz1Eq3rU6DWh8solBVkMw==',
#                 i2: 'LES+kHqt6gxS3Ch3k5GV/Q==',
#                 zh: '3XlKis5p8b5hgWF1bd9UgdW3b/8bjeC7/AQO0MH0R2I=',
#                 uh: 'SLdVolODg++SO356HusO5I/hbfOpiiOxQXj62i/MUkA=',
#                 hh: 'xx1TTDio6c75cUlsE4Atc65FbQFO1vgvVEBu0v9Ngqw=',
#             }
#         };
#         var trkjs = document.createElement('img');
#         trkjs.setAttribute('src', '/cdn-cgi/images/trace/jsch/js/transparent.gif?ray=7bdb9ed3fc3d1005');
#         trkjs.setAttribute('alt', '');
#         trkjs.setAttribute('style', 'display: none');
#         document.body.appendChild(trkjs);
#         var cpo = document.createElement('script');
#         cpo.src = '/cdn-cgi/challenge-platform/h/b/orchestrate/jsch/v1?ray=7bdb9ed3fc3d1005';
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.slice(0, location.href.length - window._cf_chl_opt.cOgUHash.length).indexOf('?') !== -1 ? '?' : location.search;
#         if (window.history && window.history.replaceState) {
#             var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#             history.replaceState(null, null, "\/doi\/10.1073\/pnas.0501761102?__cf_chl_rt_tk=kOEGTGYURTpiryGROyU4l8xvgzSo_l4rIxyyXxNaT7A-1682478497-0-gaNycGzNCaU" + window._cf_chl_opt.cOgUHash);
#             cpo.onload = function() {
#                 history.replaceState(null, null, ogU);
#             };
#         }
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
# </script>
# </body>
# </html>

# %%
for div in soup.find_all("div"):
    print(div)
# Out:
# <div class="main-wrapper" role="main">
# <div class="main-content">
# <noscript>
# <div id="challenge-error-title">
# <div class="h2">
# <span class="icon-wrapper">
# <div class="heading-icon warning-icon"></div>
# </span>
# <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
# </div>
# </div>
# </noscript>
# <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/jsch/nojs/transparent.gif?ray=7bdb9ed3fc3d1005')"></div>
# <form action="/doi/10.1073/pnas.0501761102?__cf_chl_f_tk=kOEGTGYURTpiryGROyU4l8xvgzSo_l4rIxyyXxNaT7A-1682478497-0-gaNycGzNCaU" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
# <input name="md" type="hidden" value="mqAcFgr_xw8Gy1l.jwQOecpl4LEHR_Xfd8WKoLaxvEg-1682478497-0-Afwk5TtD5NCK3Brk7c0HFEISCzvV6y5Snvka7OG1QdRT5XkAkd-jCJMdNFsmpYiGbY4qsVr0oyIKRNbK91Pkz_qZMUukiQC3mCO64i4uJTi2rjLeRLdR0AGuMFjQiHZ1pN29h_Q4BkrCNvzHzSwc5_3DYWDV10AHvzno9bk01gFfxCCDggtzhKymyWtHZ-rXhf1X8wZq4df2jZhwxcP6sAus35EBoaVmRCYxYF2dxqVmiEWw1PBQHV-Wno9HwtOIAqAyZb9ZR0EyoIlpo098iNfBb3loefQhDLpeL1PnTTY0Dt5TXMbghOeLdoQGdvjL_2UeMBqx-6jjCKcKB4fGKEe4Qsg3Kn9EQAJFk9ybzNubY_hBdl_UcFKo-x4xy8X_UPxwPa3ophpb3JjtlDMxX7ypxbRcPviVvtazDAUebaf8oa4xfs3hz7ZH-2IS1G8jZicGGO8EeR23NNSI7qe6ARaA6zD04fyuZaw-FawlSMOQqfDPlJsa30ToZM5gjzSf
GJdCgYA_lRLXl0rLvCgw2qist7xreVKc3HlFOxBpqCGyaKOckGlpV30-8A9L55RBhqJL5Ms0jTItbWkETiPZ8wxWsp71UsGosFsVy7AVu8s4p3O2MAueCWGutRoEhnE3fz5mwY3bGqiHNx6zSI6y9WxsREa46z3pNqgmCpEpsAbxAmixzAbwKy46Q95gsez2W7LJ04USjtC4gk1wrf6qUDIyLC04ppUeZQbjaXIxaEmzoT"/>
# </form>
# </div>
# </div>
# <div class="main-content">
# <noscript>
# <div id="challenge-error-title">
# <div class="h2">
# <span class="icon-wrapper">
# <div class="heading-icon warning-icon"></div>
# </span>
# <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
# </div>
# </div>
# </noscript>
# <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/jsch/nojs/transparent.gif?ray=7bdb9ed3fc3d1005')"></div>
# <form action="/doi/10.1073/pnas.0501761102?__cf_chl_f_tk=kOEGTGYURTpiryGROyU4l8xvgzSo_l4rIxyyXxNaT7A-1682478497-0-gaNycGzNCaU" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
# <input name="md" type="hidden" value="mqAcFgr_xw8Gy1l.jwQOecpl4LEHR_Xfd8WKoLaxvEg-1682478497-0-Afwk5TtD5NCK3Brk7c0HFEISCzvV6y5Snvka7OG1QdRT5XkAkd-jCJMdNFsmpYiGbY4qsVr0oyIKRNbK91Pkz_qZMUukiQC3mCO64i4uJTi2rjLeRLdR0AGuMFjQiHZ1pN29h_Q4BkrCNvzHzSwc5_3DYWDV10AHvzno9bk01gFfxCCDggtzhKymyWtHZ-rXhf1X8wZq4df2jZhwxcP6sAus35EBoaVmRCYxYF2dxqVmiEWw1PBQHV-Wno9HwtOIAqAyZb9ZR0EyoIlpo098iNfBb3loefQhDLpeL1PnTTY0Dt5TXMbghOeLdoQGdvjL_2UeMBqx-6jjCKcKB4fGKEe4Qsg3Kn9EQAJFk9ybzNubY_hBdl_UcFKo-x4xy8X_UPxwPa3ophpb3JjtlDMxX7ypxbRcPviVvtazDAUebaf8oa4xfs3hz7ZH-2IS1G8jZicGGO8EeR23NNSI7qe6ARaA6zD04fyuZaw-FawlSMOQqfDPlJsa30ToZM5gjzSfel9TFrWxkN1PWQhAsJY6iEeIcfqrm8C8EKDkWzm683Se1z77f4B0UlI7S-70dwRUs_WqIP6kr9sOh-CR5NwG54726h-389-1Kor5hCYpYGeVVIK02vVCNh0I-V2pIi8yFfMGYQNKzSxNBq0drkV0zp-JFoXK1aY2ZJyoQbqstrP-AoJokVfXKr2pRiDLghrbPwNhGr1SA0KCf1Hq3KzowNg4GZFYo8LgfPeAT2L9ntFc14YKJPed4z49zpd74Yp8FkA-k4Sp_tU-ljDUY8iBMH7VlJllEkHk8Q8LhOYuNEtfgheOJEgGh2xR6MsXVozBsCRqib-btRoG5SGLZECeI4vh_F2QZqwWjfAypKojMdYjzIbD2shZo3bLrz79dSrz81YfP7PZF8y9KaHQDzd10Yrp1Np_CoLHgEdtiZ-gqXPxdieTrWTSzIkbIPxCwcrqYx6mM-VExcQpzeamXbfBbKbcT34CVUSxjxLGn0ecfYS0_OR0pkmsT-i9OrKJDDkCbrKOQ1rINr_ERS6UoC7XGUfTnusYhkqMqh26cjl4r60DV_aoQDpqK5-hYAvxPMfzHffcPFWRcc67HGCWNrMSJi6WuvYjb8dUM11AaWc9ptAePNuC6fyS0_PxsEA9Fbv0qh-MyoA1FCQfzy67Zf2FC0oEgpqIpOHRx-6izqOjqlSr_SuwMVu1aAioRTe1ZhMlRoeyDYd0RAsW23V0rz-Vgx75ncI6ZXF5FCU1JVUm4OXUjQ5R4MWaYzYfsKMkiHc9vBAIFhxvC8d44aYX7tuaXO_3IlFcZ5ZShIdJHXYpsUkQh03YxrKIjLdpIOwTFnjEaYmeVSFjy9isNUSx62nZKJSmOzmOrB1IiqvpWc5mU-FeUqKFpa0nK6XAnB06VuwXA0i-2yz-lsOHWoVz25kl35iOvSiTESM4mYXpoh6Ty8U7zJ0PTuib_F7wA4o3kHXJvKYQrCGfW9vV-4V7DdpRadwpE-AIeY2In3NKvqWiCkrsmGkjBbVO_dirxAvOe_cZ5KJcff1P0urDmJamIBcKDFnEn0PoqsVG8X3Ltm-Tk0bSsaCi6xSWJsYd4LApo4RocwdAhvNiDleQook3AHQOQ7--WrdaDzroCqg3L0rMkv2wCPq-LdgZaHxdE29urn9WuOP-Edaq529t1hX5I0RZaL6dg8E5Sype79AajDeG1-kSSNHM0c3wDFObP0lr1D26YHLh5tWX0c7XfEOFLFToVFsMd-YBMXKUc-ksLigG7WUffUPxgoxfpby_7cKdwPfL-gaJW5vAoMBPS9q--tP6baY3ckw6yib43Ud5LBJYYG3i6ojL2VZGDfttyHpiiJga0uTgX247DaM41fq2U8Kb2KUf4canZiYO1-YPGypiYdc-zYthfJ39Pd0xME1zsvkWVaeuay4dZdAKQ9zhX536aYclgXSLDhUwGht5CusxMK4ReUHYfGdtGW-T7B0p4v7BODLTbQRSLljMVfAOwt0AXZmqJ3p7dkR9fM5XQULKzN3heVwsYPxYOUyY9fZY_LONv7f0ELDftFvJdKwFkUIGc1TMi_JZkWQdmDbruMU17u3Zooz7JjD-q3Fuuak6us_QMvHqLVChYYugEukNIDxRoLN9_rUySMSrAJonKzJqft7wUhzz0wYXS4yFwJewLKGJdCgYA_lRLXl0rLvCgw2qist7xreVKc3HlFOxBpqCGyaKOckGlpV30-8A9L55RBhqJL5Ms0jTItbWkETiPZ8wxWsp71UsGosFsVy7AVu8s4p3O2MAueCWGutRoEhnE3fz5mwY3bGqiHNx6zSI6y9WxsREa46z3pNqgmCpEpsAbxAmixzAbwKy46Q95gsez2W7LJ04USjtC4gk1wrf6qUDIyLC04ppUeZQbjaXIxaEmzoT"/>
# </form>
# </div>
# <div id="challenge-error-title">
# <div class="h2">
# <span class="icon-wrapper">
# <div class="heading-icon warning-icon"></div>
# </span>
# <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
# </div>
# </div>
# <div class="h2">
# <span class="icon-wrapper">
# <div class="heading-icon warning-icon"></div>
# </span>
# <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
# </div>
# <div class="heading-icon warning-icon"></div>
# <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/jsch/nojs/transparent.gif?ray=7bdb9ed3fc3d1005')"></div>
